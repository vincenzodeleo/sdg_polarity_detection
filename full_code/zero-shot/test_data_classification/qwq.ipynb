# %% [markdown]
# # PREPARAZIONE DATASET DI TRAIN

# %%
experiment_name = '2025.01.09-01_Qwq_zero_shot'

# %%
pip install -q datasets --progress-bar off
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %%
import pandas as pd
import pickle
from datasets import Dataset

# %%
from google.colab import drive
from IPython.display import Image, display

mount_point = "/content/gdrive"
base_path = mount_point + "/MyDrive/Colab/SDG/data"

drive.mount(mount_point, force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
output_data_path = base_path + "/../AnalisiTesti/FineTuning/Qwq-32B/data/output/" + experiment_name

# %%
df = pd.read_excel(base_path + "/../AnalisiTesti/data/output/RisultatiSentiment_5modelli_CON_LABEL_FINALE.xlsx")
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  text_id  \
# 0                0           0     1528
# 1                1           1     2389
# 2                2           2     5801
# 3                3           3      420
# 4                4           4     5138
# ...            ...         ...      ...
# 6395          6395        6395     2870
# 6396          6396        6396     6330
# 6397          6397        6397     2723
# 6398          6398        6398     6710
# 6399          6399        6399     1947
#
#                                                    text  sdg_true  \
# 0     Indeed, available empirical evidence typically...        10
# 1     Having a secure and up-to-date knowledge datab...        15
# 2     It may be commonplace to state that the world ...        16
# 3     From the environmental protection point of vie...        12
# 4     In other countries, such as the Czech Republic...        10
# ...                                                 ...       ...
# 6395  1. What's morality got to do with it? making t...        16
# 6396  As an organising principle within multi-level ...        16
# 6397  This article examines the neo-conservative cri...        16
# 6398  In Phillips Petroleum Co. v. Shutts, the Unite...        16
# 6399  For the past half a century, Latin American sc...        16
#
#      sentiment_Llama3 sentiment_Mixtral sentiment_Phi3 sentiment_Gemma  \
# 0             neutral           neutral       negative        negative
# 1             neutral          positive       positive        positive
# 2             neutral           neutral        neutral        positive
# 3            positive          positive       positive        positive
# 4             neutral           neutral       positive        positive
# ...               ...               ...            ...             ...
# 6395          neutral           neutral        neutral         neutral
# 6396          neutral           neutral        neutral        positive
# 6397          neutral           neutral        neutral        negative
# 6398          neutral           neutral        neutral        positive
# 6399          neutral           neutral        neutral        negative
#
#      sentiment_Qwen vote_level     label
# 0          negative     Silver  negative
# 1          positive       Gold  positive
# 2          negative     Silver   neutral
# 3          positive   Platinum  positive
# 4          positive     Silver  positive
# ...             ...        ...       ...
# 6395        neutral   Platinum   neutral
# 6396        neutral       Gold   neutral
# 6397       negative     Silver   neutral
# 6398        neutral       Gold   neutral
# 6399       negative     Silver   neutral
#
# [6400 rows x 12 columns]

# %%
# BISOGNA RIMUOVERE DAL DATASET I TESTI UTILIZZATI PER L'ETICHETTATURA MANUALE DEL DATASET DI TEST

# df[df.text_id==210]

df_test = pd.read_excel(base_path + "/../AnalisiTesti/data/output/RisultatiSentiment_EtichetatturaManuale_DatasetDiTest_CON_LABEL_FINALE.xlsx").drop(columns=['Unnamed: 0'])
df_test
# Out:
#      text_id                                               text  sdg_true  \
# 0        210  The Brazilian Instituto de Pesquisa Economica ...         1
# 1        251  While the growth effect predominated in practi...         1
# 2        441  Nevertheless, the use of indices as a form of ...         1
# 3        591  If it is high, then public policies designed t...         1
# 4       1250  Results for countries using national panels ad...         1
# ..       ...                                                ...       ...
# 571     5801  It may be commonplace to state that the world ...        16
# 572     6119  Sexual citizenship and sexual rights scholarsh...        16
# 573     6551  Legal pluralism is a phenomenon defined differ...        16
# 574     6618  This article discusses the extent, impacts, an...        16
# 575     6628  An important transformation took place in inte...        16
#
#         label
# 0    positive
# 1     neutral
# 2    positive
# 3    positive
# 4     neutral
# ..        ...
# 571   neutral
# 572  positive
# 573  positive
# 574  negative
# 575  positive
#
# [576 rows x 4 columns]

# %%
# BISOGNA RIMUOVERE DAL DATASET I TESTI UTILIZZATI PER L'ETICHETTATURA MANUALE DEL DATASET DI TEST

df = df[~df.text_id.isin(df_test.text_id)]
df
# Out:
#       Unnamed: 0.1  Unnamed: 0  text_id  \
# 0                0           0     1528
# 1                1           1     2389
# 3                3           3      420
# 4                4           4     5138
# 5                5           5     3504
# ...            ...         ...      ...
# 6394          6394        6394     2370
# 6396          6396        6396     6330
# 6397          6397        6397     2723
# 6398          6398        6398     6710
# 6399          6399        6399     1947
#
#                                                    text  sdg_true  \
# 0     Indeed, available empirical evidence typically...        10
# 1     Having a secure and up-to-date knowledge datab...        15
# 3     From the environmental protection point of vie...        12
# 4     In other countries, such as the Czech Republic...        10
# 5     They also show causality in both directions (t...         7
# ...                                                 ...       ...
# 6394  Purpose – This article aims to explore the con...        16
# 6396  As an organising principle within multi-level ...        16
# 6397  This article examines the neo-conservative cri...        16
# 6398  In Phillips Petroleum Co. v. Shutts, the Unite...        16
# 6399  For the past half a century, Latin American sc...        16
#
#      sentiment_Llama3 sentiment_Mixtral sentiment_Phi3 sentiment_Gemma  \
# 0             neutral           neutral       negative        negative
# 1             neutral          positive       positive        positive
# 3            positive          positive       positive        positive
# 4             neutral           neutral       positive        positive
# 5            positive          positive       positive        positive
# ...               ...               ...            ...             ...
# 6394         positive           neutral       positive        positive
# 6396          neutral           neutral        neutral        positive
# 6397          neutral           neutral        neutral        negative
# 6398          neutral           neutral        neutral        positive
# 6399          neutral           neutral        neutral        negative
#
#      sentiment_Qwen vote_level     label
# 0          negative     Silver  negative
# 1          positive       Gold  positive
# 3          positive   Platinum  positive
# 4          positive     Silver  positive
# 5          positive   Platinum  positive
# ...             ...        ...       ...
# 6394       positive       Gold  positive
# 6396        neutral       Gold   neutral
# 6397       negative     Silver   neutral
# 6398        neutral       Gold   neutral
# 6399       negative     Silver   neutral
#
# [5824 rows x 12 columns]

# %%
6400-576
# Out:
# 5824

# %%
# text = df.text.iloc[0]
# sdg_true = df.sdg_true.iloc[0]

# template = f"""Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:

#   - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.

#   - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.

#   - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.

# Return the result in JSON format with 1 key:

#   - "label": The assigned label for the input text [this key/value pair is mandatory].


# INPUT TEXT: \"{text}\"
# SDG_CLASSIFICATION: \"SDG-{sdg_true}\"
# LABEL: """

# print(template)

# %%
# Creazione del dataset di train
dataset_data = [
    [
        {"content": f"""Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:

  - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.

  - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.

  - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.

Return the result in JSON format with 1 key:

  - "label": The assigned label for the input text [this key/value pair is mandatory].


INPUT TEXT: \"{row["text"]}\"
SDG_CLASSIFICATION: \"SDG-{row["sdg_true"]}\"
OUTPUT: """, "role": "user"},
        {"content": row["label"], "role": "assistant"}
    ]
    for _, row in df.iterrows()
]

# %%
# Conversione in formato Dataset di HuggingFace
dataset = Dataset.from_dict({"conversations": dataset_data})

# %%
# Visualizzazione del dataset
print(dataset)
# Out:
# Dataset({
#     features: ['conversations'],
#     num_rows: 5824
# })

# %%
print(dataset['conversations'][0][0]['content'], dataset['conversations'][0][1]['content'])
# Out:
# Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:
#
#   - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.
#
#   - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.
#
#   - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.
#
# Return the result in JSON format with 1 key:
#
#   - "label": The assigned label for the input text [this key/value pair is mandatory].
#
#
# INPUT TEXT: "Indeed, available empirical evidence typically suggests that, when targeting employment protection on a specific group of workers, legislation usually induces substitution across groups as regards hiring (see e.g. Acemoglu and Angrist, 2001, Femandez-Kranz and Rodriguez-Planas, 2011). Blanchard and Wolfers (2000) and Nickell et al. ( Recent OECD work, identifying the effect of dismissal restrictions on employment through the likely heterogeneity of its effects across industries or firm types, find that these regulations reduce employment resilience to output shocks (e.g. OECD, 2011a, Bassanini, 2012), which helps explaining the limited employment elasticity of the recent recession (Gal et al.,"
# SDG_CLASSIFICATION: "SDG-10"
# OUTPUT:  negative

# %%
# Creazione del dataset di test
# test_dataset_data = [
#     [
#         {"content": f"""Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:

#   - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.

#   - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.

#   - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.

# Return the result in JSON format with 1 key:

#   - "label": The assigned label for the input text [this key/value pair is mandatory].


# INPUT TEXT: \"{row["text"]}\"
# SDG_CLASSIFICATION: \"SDG-{row["sdg_true"]}\"
# OUTPUT: """, "role": "user"},
#         {"content": row["label"], "role": "assistant"}
#     ]
#     for _, row in df_test.iterrows()
# ]

test_dataset_data = []
test_dataset_data_map_for_text_id_and_sdg_true = {}

for _, row in df_test.iterrows():

  prompt = f"""Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:

  - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.

  - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.

  - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.

Return the result in JSON format with 1 key:

  - "label": The assigned label for the input text [this key/value pair is mandatory].


INPUT TEXT: \"{row["text"]}\"
SDG_CLASSIFICATION: \"SDG-{row["sdg_true"]}\"
OUTPUT: """

  test_dataset_data.append(
      [
        {"content": prompt, "role": "user"},
        {"content": row["label"], "role": "assistant"}
    ]
  )

  #scrivo
  test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))] = {"text_id": row["text_id"], "sdg_true": row["sdg_true"]}

  #leggo
  # test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))]

  #leggo 2
  # print(test_dataset_data_map_for_text_id_and_sdg_true[list(test_dataset_data_map_for_text_id_and_sdg_true.keys())[0]])

#   break

# test_dataset = Dataset.from_dict({"conversations": test_dataset_data})

# for data in test_dataset:
#   prompt = ""
#   json_list = data["conversations"]
#   # print(json_list)
#   for j in json_list:
#     if j['role']=='user':
#       prompt = j['content']
#   # print(prompt)
#   # # print(hash(prompt))
#   # print(test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))])
#   print(test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))]['text_id'])
#   # print(test_dataset_data_map_for_text_id_and_sdg_true[prompt.strip().replace('\n', ' ')]['sdg_true'])
#   # break


# AGGIUNGO QUESTO PER POTER RIMAPPARE SUCCESSIVAMENTE OGNI TESTO CON IL SUO TEXT_ID
# import hashlib
# test_dataset_data_map_for_text_id_and_sdg_true = {}
# for _, row in df_test.iterrows():
#   test_dataset_data_map_for_text_id_and_sdg_true[hash(f"""Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:

#   - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.

#   - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously …INPUT TEXT: \"{row["text"]}\"
# SDG_CLASSIFICATION: \"SDG-{row["sdg_true"]}\"
# OUTPUT: """)] = {
#     "text_id": row["text_id"],
#     "sdg_true": row["sdg_true"]
# }

# %%
# list(test_dataset_data_map_for_text_id_and_sdg_true.keys())[:3]

# %%
# list(test_dataset_data_map_for_text_id_and_sdg_true.keys())[0]==prompt.strip().replace('\n', ' ')

# %%
# prompt.strip().replace('\n', ' ')

# %%
# for k in test_dataset_data_map_for_text_id_and_sdg_true:
#   print(k)
#   print(test_dataset_data_map_for_text_id_and_sdg_true[k])
#   break

# %%
# Conversione in formato Dataset di HuggingFace
test_dataset = Dataset.from_dict({"conversations": test_dataset_data})

# %%
# Visualizzazione del dataset
print(test_dataset)
# Out:
# Dataset({
#     features: ['conversations'],
#     num_rows: 576
# })

# %%
print(test_dataset['conversations'][0][0]['content'], test_dataset['conversations'][0][1]['content'])
# Out:
# Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:
#
#   - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.
#
#   - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.
#
#   - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.
#
# Return the result in JSON format with 1 key:
#
#   - "label": The assigned label for the input text [this key/value pair is mandatory].
#
#
# INPUT TEXT: "The Brazilian Instituto de Pesquisa Economica Aplicada (Institute of Applied Economic Research, IPEA) has noted that every Real (BRL) invested in the programme increases GDP by BRL 1.44. The 16 million children and adolescents whose school attendance is monitored by the programme show lower rates of truancy and are performing at a level equal to the average student in the public school system, despite their impoverished economic condition. This will lead to a future for these children far different from the situation of exclusion suffered by their parents and grandparents."
# SDG_CLASSIFICATION: "SDG-1"
# OUTPUT:  positive

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth on your own computer, follow the installation instructions on our Github page [here](https://github.com/unslothai/unsloth?tab=readme-ov-file#-installation-instructions).
#
# You will learn how to do [data prep](#Data), how to [train](#Train), how to [run the model](#Inference), & [how to save it](#Save) (eg for Llama.cpp).
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**
#
# Features in the notebook:
# 1. Uses Maxime Labonne's [FineTome 100K](https://huggingface.co/datasets/mlabonne/FineTome-100k) dataset.
# 1. Convert ShareGPT to HuggingFace format via `standardize_sharegpt`
# 2. Train on Completions / Assistant only via `train_on_responses_only`
# 3. Unsloth now supports Torch 2.4, all TRL & Xformers versions & Python 3.12!

# %%
# %%capture
# !pip install unsloth
# Also get the latest nightly Unsloth!
# !pip uninstall unsloth -y && pip install --upgrade --no-cache-dir --no-deps git+https://github.com/unslothai/unsloth.git

# %% [markdown]
# * We support Llama, Mistral, Phi-3, Gemma, Yi, DeepSeek, Qwen, TinyLlama, Vicuna, Open Hermes etc
# * We support 16bit LoRA or 4bit QLoRA. Both 2x faster.
# * `max_seq_length` can be set to anything, since we do automatic RoPE Scaling via [kaiokendev's](https://kaiokendev.github.io/til) method.
# * [**NEW**] We make Gemma-2 9b / 27b **2x faster**! See our [Gemma-2 9b notebook](https://colab.research.google.com/drive/1vIrqH5uYDQwsJ4-OO3DErvuv4pBgVwk4?usp=sharing)
# * [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048 # Choose any! We auto support RoPE Scaling internally!
dtype = None # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True # Use 4bit quantization to reduce memory usage. Can be False.

# 4bit pre quantized models we support for 4x faster downloading + no OOMs.
fourbit_models = [
    "unsloth/Meta-Llama-3.1-8B-bnb-4bit",      # Llama-3.1 15 trillion tokens model 2x faster!
    "unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit",
    "unsloth/Meta-Llama-3.1-70B-bnb-4bit",
    "unsloth/Meta-Llama-3.1-405B-bnb-4bit",    # We also uploaded 4bit for 405b!
    "unsloth/Mistral-Nemo-Base-2407-bnb-4bit", # New Mistral 12b 2x faster!
    "unsloth/Mistral-Nemo-Instruct-2407-bnb-4bit",
    "unsloth/mistral-7b-v0.3-bnb-4bit",        # Mistral v3 2x faster!
    "unsloth/mistral-7b-instruct-v0.3-bnb-4bit",
    "unsloth/Phi-3.5-mini-instruct",           # Phi-3.5 2x faster!
    "unsloth/Phi-3-medium-4k-instruct",
    "unsloth/gemma-2-9b-bnb-4bit",
    "unsloth/gemma-2-27b-bnb-4bit",            # Gemma 2x faster!
] # More models at https://huggingface.co/unsloth

model, tokenizer = FastLanguageModel.from_pretrained(
    # Can select any from the below:
    # "unsloth/Qwen2.5-0.5B", "unsloth/Qwen2.5-1.5B", "unsloth/Qwen2.5-3B"
    # "unsloth/Qwen2.5-14B",  "unsloth/Qwen2.5-32B",  "unsloth/Qwen2.5-72B",
    # And also all Instruct versions and Math. Coding verisons!
    # model_name = "unsloth/Qwen2.5-7B-Instruct",
    model_name = "unsloth/QwQ-32B-Preview-unsloth-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
    # token = "hf_...", # use one if using gated models like meta-llama/Llama-2-7b-hf
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.1.5: Fast Qwen2 patching. Transformers: 4.47.1.
#    \\   /|    GPU: NVIDIA A100-SXM4-40GB. Max memory: 39.564 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.5.1+cu121. CUDA: 8.0. CUDA Toolkit: 12.1. Triton: 3.1.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post1. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json:   0%|          | 0.00/271k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/5 [00:00<?, ?it/s]
# model-00001-of-00005.safetensors:   0%|          | 0.00/4.99G [00:00<?, ?B/s]
# model-00002-of-00005.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00005.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00005.safetensors:   0%|          | 0.00/4.84G [00:00<?, ?B/s]
# model-00005-of-00005.safetensors:   0%|          | 0.00/3.23G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/5 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/236 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.41k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/605 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/614 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/11.4M [00:00<?, ?B/s]

# %% [markdown]
# We now add LoRA adapters so we only need to update 1 to 10% of all parameters!

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r = 16, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 16,
    lora_dropout = 0, # Supports any, but = 0 is optimized
    bias = "none",    # Supports any, but = "none" is optimized
    # [NEW] "unsloth" uses 30% less VRAM, fits 2x larger batch sizes!
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = False,  # We support rank stabilized LoRA
    loftq_config = None, # And LoftQ
)
# Out:
# Unsloth 2025.1.5 patched 64 layers with 64 QKV layers, 64 O layers and 64 MLP layers.

# %% [markdown]
# <a name="Data"></a>
# ### Data Prep
# We now use the `Qwen-2.5` format for conversation style finetunes. We use [Maxime Labonne's FineTome-100k](https://huggingface.co/datasets/mlabonne/FineTome-100k) dataset in ShareGPT style. But we convert it to HuggingFace's normal multiturn format `("role", "content")` instead of `("from", "value")`/ Qwen2.5 renders multi turn conversations like below:
#
# ```
# <|im_start|>system
# You are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Hello!<|im_end|>
# <|im_start|>assistant
# Hey there! How are you?<|im_end|>
# <|im_start|>user
# I'm great thanks!<|im_end|>
# ```
#
# We use our `get_chat_template` function to get the correct chat template. We support `zephyr, chatml, mistral, llama, alpaca, vicuna, vicuna_old, phi3, llama3` and more.

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "qwen-2.5",
)

def formatting_prompts_func(examples):
    convos = examples["conversations"]
    texts = [tokenizer.apply_chat_template(convo, tokenize = False, add_generation_prompt = False) for convo in convos]
    return { "text" : texts, }
pass

# from datasets import load_dataset
# dataset = load_dataset("mlabonne/FineTome-100k", split = "train") # COMMENTATO PER UTILIZZARE IL DATASET DEL SENTIMENT DEGLI SDG

# %% [markdown]
# We now use `standardize_sharegpt` to convert ShareGPT style datasets into HuggingFace's generic format. This changes the dataset from looking like:
# ```
# {"from": "system", "value": "You are an assistant"}
# {"from": "human", "value": "What is 2+2?"}
# {"from": "gpt", "value": "It's 4."}
# ```
# to
# ```
# {"role": "system", "content": "You are an assistant"}
# {"role": "user", "content": "What is 2+2?"}
# {"role": "assistant", "content": "It's 4."}
# ```

# %%
from unsloth.chat_templates import standardize_sharegpt
dataset = standardize_sharegpt(dataset)
dataset = dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Standardizing format:   0%|          | 0/5824 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5824 [00:00<?, ? examples/s]

# %%
test_dataset = standardize_sharegpt(test_dataset)
test_dataset = test_dataset.map(formatting_prompts_func, batched = True,)
# Out:
# Standardizing format:   0%|          | 0/576 [00:00<?, ? examples/s]
# Map:   0%|          | 0/576 [00:00<?, ? examples/s]

# %% [markdown]
# We look at how the conversations are structured for item 5:

# %%
dataset[5]["conversations"]
# Out:
# [{'content': 'Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:\n\n  - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.\n\n  - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.\n\n  - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.\n\nReturn the result in JSON format with 1 key:\n\n  - "label": The assigned label for the input text [this key/value pair is mandatory].\n\n\nINPUT TEXT: "Nunavut aims to develop entirely culturally-responsive and locally-relevant curriculum, programs, materials and assessments that also ensure their students have access to post-secondary and university entrance requirements (Nunavut Department of Education, 2007). For example, the former grade 12 standardized social studies examination has been replaced by a project-based assessment model developed in Nunavut to facilitate student assessment that combines local topics, cultural content as well as 21st century skills. The concept of Sami education differs throughout the area. On the Norwegian side there are two national curricula for the basic education 1-13, the Norwegian and the Sami. The Sami school concept for grades 1-10 reflects groups, classes or schools which are municipally owned and which follow the Sami National Curriculum, several specialized Sami schools, and for the upper secondary level two state operated schools. Also, all students are required to learn about Sami themes according to syllabi grades 1-13."\nSDG_CLASSIFICATION: "SDG-4"\nOUTPUT: ',
#   'role': 'user'},
#  {'content': 'positive', 'role': 'assistant'}]

# %% [markdown]
# And we see how the chat template transformed these conversations.
#
# **[Notice]** Qwen 2.5 Instruct's default chat template default adds `"You are Qwen, created by Alibaba Cloud. You are a helpful assistant."`, so do not be alarmed!

# %%
dataset[5]["text"]
# Out:
# '<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n<|im_start|>user\nGiven the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:\n\n  - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.\n\n  - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.\n\n  - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.\n\nReturn the result in JSON format with 1 key:\n\n  - "label": The assigned label for the input text [this key/value pair is mandatory].\n\n\nINPUT TEXT: "Nunavut aims to develop entirely culturally-responsive and locally-relevant curriculum, programs, materials and assessments that also ensure their students have access to post-secondary and university entrance requirements (Nunavut Department of Education, 2007). For example, the former grade 12 standardized social studies examination has been replaced by a project-based assessment model developed in Nunavut to facilitate student assessment that combines local topics, cultural content as well as 21st century skills. The concept of Sami education differs throughout the area. On the Norwegian side there are two national curricula for the basic education 1-13, the Norwegian and the Sami. The Sami school concept for grades 1-10 reflects groups, classes or schools which are municipally owned and which follow the Sami National Curriculum, several specialized Sami schools, and for the upper secondary level two state operated schools. Also, all students are required to learn about Sami themes according to syllabi grades 1-13."\nSDG_CLASSIFICATION: "SDG-4"\nOUTPUT: <|im_end|>\n<|im_start|>assistant\npositive<|im_end|>\n'

# %%
test_dataset[5]["conversations"]
# Out:
# [{'content': 'Given the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:\n\n  - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.\n\n  - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.\n\n  - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.\n\nReturn the result in JSON format with 1 key:\n\n  - "label": The assigned label for the input text [this key/value pair is mandatory].\n\n\nINPUT TEXT: "Such information is essential to guide integrated policies. Whereas the traditional dashboard of non-monetary indicators reflects deprivations of all people, rich and poor (and is also reported), the coordinated dashboard of consistent sub-indices that unpack the MPI is focused on the poor. The MPI and its associated statistics can be reported for more than one poverty line or cut-off."\nSDG_CLASSIFICATION: "SDG-1"\nOUTPUT: ',
#   'role': 'user'},
#  {'content': 'neutral', 'role': 'assistant'}]

# %%
test_dataset[5]["text"]
# Out:
# '<|im_start|>system\nYou are Qwen, created by Alibaba Cloud. You are a helpful assistant.<|im_end|>\n<|im_start|>user\nGiven the following input text, between triple quotes, with its associated classification label with respect to one of the Sustainable Development Goals (SDGs), further classify the text with respect to the three labels defined below:\n\n  - "positive": the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the SDG under which it was previously classified.\n\n  - "negative": the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the SDG under which it was previously classified.\n\n  - "neutral": the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the SDG under which it was previously classified.\n\nReturn the result in JSON format with 1 key:\n\n  - "label": The assigned label for the input text [this key/value pair is mandatory].\n\n\nINPUT TEXT: "Such information is essential to guide integrated policies. Whereas the traditional dashboard of non-monetary indicators reflects deprivations of all people, rich and poor (and is also reported), the coordinated dashboard of consistent sub-indices that unpack the MPI is focused on the poor. The MPI and its associated statistics can be reported for more than one poverty line or cut-off."\nSDG_CLASSIFICATION: "SDG-1"\nOUTPUT: <|im_end|>\n<|im_start|>assistant\nneutral<|im_end|>\n'

# %% [markdown]
# <a name="Train"></a>
# ### Train the model [DIASABILITATO IN QUESTO NOTEBOOK - FACCIO SOLO INFERENZA]
# Now let's use Huggingface TRL's `SFTTrainer`! More docs here: [TRL SFT docs](https://huggingface.co/docs/trl/sft_trainer). We do 60 steps to speed things up, but you can set `num_train_epochs=1` for a full run, and turn off `max_steps=None`. We also support TRL's `DPOTrainer`!

# %%
# from trl import SFTTrainer
# from transformers import TrainingArguments, DataCollatorForSeq2Seq
# from unsloth import is_bfloat16_supported

# trainer = SFTTrainer(
#     model = model,
#     tokenizer = tokenizer,
#     train_dataset = dataset,
#     dataset_text_field = "text",
#     max_seq_length = max_seq_length,
#     data_collator = DataCollatorForSeq2Seq(tokenizer = tokenizer),
#     dataset_num_proc = 2,
#     packing = False, # Can make training 5x faster for short sequences.
#     args = TrainingArguments(
#         per_device_train_batch_size = 2,
#         gradient_accumulation_steps = 4,
#         warmup_steps = 5,
#         # num_train_epochs = 1, # Set this for 1 full training run.
#         max_steps = 60,
#         learning_rate = 2e-4,
#         fp16 = not is_bfloat16_supported(),
#         bf16 = is_bfloat16_supported(),
#         logging_steps = 1,
#         optim = "adamw_8bit",
#         weight_decay = 0.01,
#         lr_scheduler_type = "linear",
#         seed = 3407,
#         output_dir = "outputs",
#         report_to = "none", # Use this for WandB etc
#     ),
# )

# %% [markdown]
# We also use Unsloth's `train_on_completions` method to only train on the assistant outputs and ignore the loss on the user's inputs.

# %%
# from unsloth.chat_templates import train_on_responses_only
# trainer = train_on_responses_only(
#     trainer,
#     instruction_part = "<|im_start|>user\n",
#     response_part = "<|im_start|>assistant\n",
# )

# %% [markdown]
# We verify masking is actually done:

# %%
# tokenizer.decode(trainer.train_dataset[5]["input_ids"])

# %%
# space = tokenizer(" ", add_special_tokens = False).input_ids[0]
# tokenizer.decode([space if x == -100 else x for x in trainer.train_dataset[5]["labels"]])

# %% [markdown]
# We can see the System and Instruction prompts are successfully masked!

# %%
#@title Show current memory stats
gpu_stats = torch.cuda.get_device_properties(0)
start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
print(f"{start_gpu_memory} GB of memory reserved.")
# Out:
# GPU = NVIDIA A100-SXM4-40GB. Max memory = 39.564 GB.
# 22.549 GB of memory reserved.

# %%
# trainer_stats = trainer.train()

# %%
# #@title Show final memory and time stats
# used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
# used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
# used_percentage = round(used_memory         /max_memory*100, 3)
# lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
# print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
# print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
# print(f"Peak reserved memory = {used_memory} GB.")
# print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
# print(f"Peak reserved memory % of max memory = {used_percentage} %.")
# print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# <a name="Inference"></a>
# ### Inference
# Let's run the model! You can change the instruction and input - leave the output blank!
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**
#
# We use `min_p = 0.1` and `temperature = 1.5`. Read this [Tweet](https://x.com/menhguin/status/1826132708508213629) for more information on why.

# %%
for data in test_dataset:
  prompt = ""
  json_list = data["conversations"]
  # print(json_list)
  for j in json_list:
    if j['role']=='user':
      prompt = j['content']
  # print(prompt)
  # # print(hash(prompt))
  # print(test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))])
  print(test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))]['text_id'])
  # print(test_dataset_data_map_for_text_id_and_sdg_true[prompt.strip().replace('\n', ' ')]['sdg_true'])
  # break
# Out:
# 210
# 251
# 441
# 591
# 1250
# 1293
# 2715
# 2724
# 2948
# 3176
# 3257
# 3284
# 3890
# 4083
# 4298
# 4332
# 4478
# 4636
# 4704
# 4773
# 5039
# 5057
# 5134
# 5212
# 5291
# 5353
# 5358
# 5869
# 5883
# 5968
# 5998
# 6143
# 6264
# 6326
# 6546
# 6711
# 29
# 48
# 117
# 194
# 496
# 646
# 894
# 1005
# 1319
# 1396
# 1642
# 1987
# 2031
# 2140
# 2167
# 2492
# 2511
# 2768
# 3205
# 3266
# 3941
# 3971
# 3987
# 4126
# 4566
# 4841
# 5748
# 5756
# 5812
# 5842
# 5948
# 6255
# 6421
# 6607
# 6688
# 6780
# 27
# 310
# 348
# 469
# 572
# 928
# 1124
# 1372
# 1422
# 1488
# 1655
# 1674
# 1677
# 1914
# 2040
# 2404
# 2638
# 2824
# 2846
# 2945
# 2992
# 3250
# 3572
# 3820
# 3854
# 4254
# 4295
# 4473
# 4653
# 5244
# 5459
# 6336
# 6355
# 6371
# 6378
# 6753
# 159
# 266
# 516
# 1292
# 1368
# 1550
# 1651
# 1743
# 1827
# 1857
# 2128
# 2151
# 2280
# 2358
# 2573
# 2940
# 3227
# 3246
# 3368
# 3407
# 3472
# 3714
# 4169
# 4217
# 4369
# 4383
# 4789
# 4793
# 4894
# 4919
# 5107
# 5137
# 5264
# 5960
# 6058
# 6619
# 74
# 226
# 378
# 504
# 566
# 639
# 771
# 772
# 1056
# 1065
# 1084
# 1219
# 1326
# 1343
# 1450
# 1799
# 2582
# 2887
# 3041
# 3067
# 3380
# 3384
# 3393
# 3480
# 3647
# 4354
# 4578
# 4676
# 4707
# 4834
# 4964
# 4988
# 5049
# 5449
# 5779
# 6281
# 114
# 130
# 650
# 822
# 919
# 983
# 1260
# 1410
# 1432
# 1765
# 1832
# 2343
# 2445
# 2936
# 2950
# 2997
# 3012
# 3014
# 3164
# 3293
# 3490
# 3669
# 3698
# 3916
# 4423
# 4480
# 5314
# 5579
# 5928
# 5944
# 6045
# 6116
# 6610
# 6626
# 6717
# 6720
# 100
# 165
# 1269
# 1324
# 1835
# 2069
# 2144
# 2251
# 2329
# 2394
# 2438
# 2643
# 2772
# 2876
# 2972
# 3074
# 3089
# 3438
# 3513
# 4113
# 4482
# 4624
# 4694
# 4955
# 4995
# 5507
# 5555
# 5626
# 5793
# 5981
# 5989
# 6044
# 6082
# 6200
# 6472
# 6719
# 107
# 125
# 134
# 624
# 753
# 809
# 934
# 1082
# 1198
# 1261
# 2027
# 2127
# 2236
# 2356
# 2530
# 3106
# 3122
# 3159
# 3317
# 3505
# 3590
# 3679
# 3758
# 4361
# 4429
# 4439
# 4564
# 5053
# 5063
# 5334
# 6056
# 6368
# 6570
# 6621
# 6656
# 6749
# 5
# 34
# 81
# 574
# 899
# 921
# 1023
# 1399
# 1489
# 1521
# 1607
# 1631
# 1977
# 2155
# 2716
# 2930
# 3090
# 3580
# 3606
# 3830
# 3958
# 4192
# 4410
# 4417
# 4747
# 4863
# 5117
# 5376
# 5399
# 5493
# 5604
# 5737
# 5740
# 6033
# 6174
# 6440
# 329
# 462
# 478
# 732
# 826
# 883
# 1052
# 1187
# 1353
# 1470
# 1821
# 1841
# 2306
# 2453
# 2550
# 2779
# 3385
# 3520
# 4055
# 4177
# 4537
# 4690
# 4691
# 4836
# 4947
# 4993
# 5150
# 5429
# 5438
# 5530
# 5634
# 5777
# 5788
# 6011
# 6184
# 6399
# 147
# 455
# 988
# 999
# 1091
# 1120
# 1139
# 1231
# 1390
# 1567
# 1573
# 1592
# 1931
# 2039
# 2514
# 2841
# 3213
# 3328
# 3478
# 3863
# 3990
# 4114
# 4150
# 4172
# 4377
# 4390
# 4803
# 4937
# 4970
# 5297
# 5977
# 6204
# 6209
# 6216
# 6413
# 6528
# 85
# 430
# 968
# 1088
# 1375
# 1387
# 1499
# 1616
# 2104
# 2178
# 2380
# 2636
# 2849
# 2996
# 3229
# 3422
# 3777
# 4026
# 4067
# 4163
# 4236
# 4325
# 4689
# 4824
# 4861
# 4903
# 4920
# 5023
# 5211
# 5389
# 5393
# 5470
# 5641
# 5976
# 6230
# 6318
# 729
# 931
# 1296
# 1555
# 1583
# 1666
# 1747
# 1796
# 2368
# 2560
# 2596
# 2628
# 2654
# 2818
# 2890
# 3003
# 3050
# 3092
# 3144
# 3175
# 3324
# 3633
# 3828
# 3845
# 4013
# 4440
# 4565
# 4906
# 5252
# 5378
# 5724
# 6017
# 6066
# 6080
# 6366
# 6637
# 240
# 410
# 778
# 1080
# 1144
# 1363
# 1405
# 1577
# 1782
# 2067
# 2090
# 2139
# 2254
# 2510
# 2754
# 2770
# 2808
# 3209
# 3360
# 3687
# 3887
# 4041
# 4082
# 4115
# 4406
# 4604
# 4717
# 5038
# 5132
# 5430
# 5621
# 5677
# 5902
# 5933
# 6496
# 6727
# 25
# 207
# 300
# 412
# 524
# 805
# 893
# 1610
# 1618
# 1882
# 2047
# 2084
# 2141
# 2205
# 2208
# 2647
# 2937
# 2951
# 2985
# 3146
# 3194
# 3253
# 3665
# 3870
# 3933
# 4729
# 4739
# 5286
# 5415
# 5475
# 5508
# 5636
# 6245
# 6396
# 6522
# 6584
# 103
# 535
# 592
# 651
# 1048
# 1197
# 1509
# 1837
# 1864
# 1982
# 2032
# 2870
# 3011
# 3237
# 3381
# 4033
# 4148
# 4197
# 4462
# 4710
# 4754
# 4777
# 4842
# 5201
# 5229
# 5238
# 5468
# 5471
# 5502
# 5622
# 5721
# 5801
# 6119
# 6551
# 6618
# 6628

# %%
# list(test_dataset_data_map_for_text_id_and_sdg_true.keys())[0]==prompt.strip().replace('\n', ' ')

# %%
# list(test_dataset_data_map_for_text_id_and_sdg_true.keys())[0]

# %%
# prompt.strip().replace('\n', ' ')

# %%
# from transformers import LogitsProcessor

# class ExcludePromptLogitsProcessor(LogitsProcessor):
#     def __init__(self, prompt_ids):
#         self.prompt_ids = prompt_ids

#     def __call__(self, input_ids, scores):
#         for prompt_id in self.prompt_ids:
#             scores[:, prompt_id] = -float("inf")  # Penalizza fortemente i token del prompt
#         return scores

# %%
from unsloth.chat_templates import get_chat_template

tokenizer = get_chat_template(
    tokenizer,
    chat_template = "qwen-2.5",
)
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

cnt=0
for data in test_dataset:
  if cnt>=6:
    prompt = ""
    sdg_true = -1
    text_id = -1
    json_list = data["conversations"]
    for j in json_list:
      if j['role']=='user':
        prompt = j['content']
        sdg_true = test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))]['sdg_true']
        text_id = test_dataset_data_map_for_text_id_and_sdg_true[hash(prompt.strip().replace('\n', ' '))]['text_id']
    # print(prompt)
    print("\n###########################################################################################")
    print(cnt, text_id)

    messages = [
        # {"role": "user", "content": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
        {"role": "user", "content": prompt}
    ]
    inputs = tokenizer.apply_chat_template(
        messages,
        tokenize = True,
        add_generation_prompt = True, # Must add for generation
        return_tensors = "pt",
    ).to("cuda")

    # prompt_ids = inputs[0].tolist()
    # logits_processor = [ExcludePromptLogitsProcessor(prompt_ids)]

    outputs = model.generate(
        input_ids = inputs,
        max_new_tokens = 2048,
        use_cache = True,
        temperature = 1.5,
        min_p = 0.1,
        # no_repeat_ngram_size=len(inputs),
        # eos_token_id=inputs[0].tolist()[-1],
        # repetition_penalty=1.2,
        # logits_processor=logits_processor
    )

    generated_text = tokenizer.batch_decode(outputs)[0]

    result_extended = (cnt, text_id, sdg_true, generated_text)

    # print(generated_text)
    if 'json' in generated_text.lower():
      print(generated_text.lower().split('json')[-1])
    else:
      raise(Exception("JSON not found in generated text"))


    with open(output_data_path+f'/sdg_classification_{text_id}.pkl', 'wb') as f:
        pickle.dump(result_extended, f)


    # if "<|im_end|>" not in generated_text.lower().split('json')[-1]:
    #   raise(Exception("Incomplete output"))

  cnt+=1

  # break
# Out:
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Streaming output truncated to the last 5000 lines.
# - **neutral**: the text is not neutral because it clearly indicates a negative impact on the goals of sdg-7.
#
# thus, the appropriate label is "negative".<|im_end|>
#
# ###########################################################################################
# 221 2069
#
# {"label": "positive"}
# ```
#
# **final output**
#
# \[{"label":"positive"}\]<|im_end|>
#
# ###########################################################################################
# 222 2144
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "this circular relationship — the energy-transformation nexus — is central to the development process. it discusses the linkages between energy supply and sustainable and inclusive structural transformation. following an examination of the patterns of energy supply and demand in least developed countries (ldcs) and their differences from other groups of countries in section b. section c elaborates on the energy-transformation nexus."
# sdg_classification: "sdg-7"
# output: <|im_end|>
# <|im_start|>assistant
# given the input text and its sdg classification as sdg-7, which is "affordable and clean energy," i need to classify the text into one of three labels: "positive," "negative," or "neutral," based on whether the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of or against the goal indicated by the sdg.
#
# first, let's understand sdg-7: affordable and clean energy. the goal aims to ensure access to affordable, reliable, sustainable, and modern energy for all. it encompasses increasing the share of renewable energy, improving energy efficiency, and expanding access to modern energy services.
#
# now, analyzing the input text:
#
# "this circular relationship — the energy-transformation nexus — is central to the development process. it discusses the linkages between energy supply and sustainable and inclusive structural transformation. following an examination of the patterns of energy supply and demand in least developed countries (ldcs) and their differences from other groups of countries in section b. section c elaborates on the energy-transformation nexus."
#
# the text talks about the relationship between energy supply and structural transformation, specifically in the context of least developed countries (ldcs). it mentions "sustainable and inclusive structural transformation," which aligns with the objectives of sdg-7, as it suggests a focus on sustainable energy practices.
#
# however, the text is descriptive and informative, discussing linkages and patterns without explicitly stating whether these linkages lead to significant advancement in favor or against the sdg. it seems to be setting up a discussion or a report that will explore these topics in more detail in subsequent sections.
#
# given that the text does not explicitly state or imply that the discussed linkages lead to a significant advancement in favor or against sdg-7, but rather sets the stage for such a discussion, it is appropriate to classify it as "neutral."
#
# therefore, the output should be:
#
# {
#   "label": "neutral"
# }<|im_end|>
#
# ###########################################################################################
# 223 2251
#
#
# {
#
# "label": "neutral"
#
# }
#
# ```
#
# **reasoning**
#
# the text discusses investment in gas and coal infrastructure within two scenarios but does not provide sufficient context to determine whether these investments significantly advance towards or against the goals of sdg-7 (affordable and clean energy). while reductions in coal investment may be positive, the continued investment in fossil fuels, including gas, without information on the overall energy mix or renewable investments, leads to a neutral classification.<|im_end|>
#
# ###########################################################################################
# 224 2329
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 225 2394
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 226 2438
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 227 2643
#
# {
#   "label": "neutral"
# }
# ```
#
# **final answer**
#
# \[ \boxed{\text{neutral}} \] <|im_end|>
#
# ###########################################################################################
# 228 2772
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 229 2876
#
# {
#   "label": "positive"
# }
# ```
#
# **explanation:**
#
# the text discusses measures that lower energy tariffs, improve energy connectivity, and emphasize transparency and minimization of environmental and social impacts, all of which align positively with sdg-7's objective of ensuring affordable and clean energy for all.<|im_end|>
#
# ###########################################################################################
# 230 2972
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 231 3074
#
# {
#   "label": "positive"
# }
# ```
#
# **justification:**
#
# the text discusses reductions in the costs of renewable energy technologies, the use of subsidies to accelerate electrification, and the potential for countries to achieve sustainable energy consumption levels with less international assistance. these points align positively with the objectives of sdg-7, indicating significant advancements in favor of affordable and clean energy.<|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 232 3089
#
#
# {
#
# "label": "neutral"
#
# }
#
# ```
#
# **reasoning**
#
# the input text discusses the technical requirements and challenges of nuclear power plants, specifically regarding their electrical stability and grid connections. it mentions higher connection costs compared to thermal plants but does not directly address the impact on the affordability or cleanliness of energy, which are key aspects of sdg 7. therefore, the text is classified as "neutral" with respect to sdg 7.<|im_end|>
#
# ###########################################################################################
# 233 3438
#  format with the key "label" indicating the classification.
#
# this approach provides a basic framework for classifying texts based on their alignment with sdg-7 objectives. for more accurate results, advanced nlp techniques and machine learning models could be employed.<|im_end|>
#
# ###########################################################################################
# 234 3513
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 235 4113
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
# - **text analysis**: the input text discusses the benefits of distributed renewable energy and energy efficiency improvements in minimizing environmental and economic costs. it explains how these measures reduce peak electricity demand, minimize transmission losses and bottlenecks, and mutually support each other to enable more feasible energy applications.
# - **alignment with sdg-7**: sdg-7 aims for affordable and clean energy for all. the text promotes the use of renewable energy and energy efficiency, which are key components of this goal.
# - **classification**: given that the text supports and advances the objectives of sdg-7, it is classified as "positive".<|im_end|>
#
# ###########################################################################################
# 236 4482
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "system costs in this study are defined as the total costs above plant-leuel costs to supply electricity at a given load and given level of security of supply. in principle, this definition could include costs external to the electricity market such as environmental costs or security of supply impacts. this study, however, focuses primarily on the costs accruing inside the electricity system to producers, consumers as well as transport and distribution system operators. a large subset of these costs are the monetisable system costs that are mediated by the electricity grid and are referred to in the following as “grid-level system costs” or “grid costs”."
# sdg_classification: "sdg-7"
# output: <|im_end|>
# <|im_start|>assistant
# {
#   "label": "neutral"
# }<|im_end|>
#
# ###########################################################################################
# 237 4624
#
# {
#   "label": "negative"
# }
# ```
#
# ### explanation
#
# 1. **text analysis**:
#    - the withdrawal of the united states from the agreement casts doubt on global efforts to combat climate change, which is crucial for sdg-7.
#    - the complexity of investigating market conditions and the risk of carbon leakage indicates challenges in achieving sustainable energy goals.
#
# 2. **classification**:
#    - the text highlights challenges and potential setbacks in achieving sdg-7, making it a negative implication for the goal.
#
# therefore, the label assigned is "negative".<|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 238 4694
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 239 4955
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 240 4995
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 241 5507
#
# {
#   "label": "positive"
# }
# ```
#
# **final answer**
#
# \[ \boxed{\text{positive}} \]<|im_end|>
#
# ###########################################################################################
# 242 5555
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 243 5626
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 244 5793
#
# {
#   "label": "positive"
# }
# ```
#
# **explanation**
#
# the text describes the beginning of a golden age for wind power development in china, which is a positive advancement towards the goal of affordable and clean energy as per sdg 7. although there are challenges mentioned, such as domestic companies lagging behind foreign competitors, the overall direction is towards increased renewable energy production, which is favorable for sdg 7.<|im_end|>
#
# ###########################################################################################
# 245 5981
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
# - **input text analysis**:
#   - the text discusses practical actions to improve energy efficiency.
#   - it emphasizes climate resiliency for energy-efficient buildings.
#   - it suggests making these measures mandatory for new homes.
#
# - **alignment with sdg-7**:
#   - improving energy efficiency directly supports sdg-7.
#   - ensuring climate resiliency is crucial for the long-term sustainability of energy solutions, aligning with sdg-7.
#   - mandatory measures for new homes indicate a proactive policy approach to achieve sdg-7 objectives.
#
# - **classification**:
#   - the text is positive because it advocates for actions that support sdg-7.
#   - there are no elements in the text that oppose or are neutral to sdg-7.
#
# thus, the label assigned is "positive".<|im_end|>
#
# ###########################################################################################
# 246 5989
#
#
# {
#
#   "label": "positive"
#
# }
#
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 247 6044
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 248 6082
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 249 6200
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 250 6472
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
#
# the text addresses issues hindering effective electricity distribution in rural areas due to political pressures and suggests implementing a predetermined plan and apolitical monitoring to improve the situation. this proposal is aimed at enhancing rural electrification, which is a key component of sdg-7. therefore, the text is classified as "positive" because it advocates for measures that should lead to improved access to electricity, thereby supporting the objectives of sdg-7.<|im_end|>
#
# ###########################################################################################
# 251 6719
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
# - **investments in alternative energy and clean technologies**: these directly contribute to increasing the share of renewable and clean energy sources, which is a key objective of sdg-7.
# - **micro-credits**: although not directly related to energy, micro-credits can support small-scale energy projects or help communities access clean energy solutions, thereby indirectly supporting sdg-7.
# - **energy efficiency in real estate**: improving energy efficiency reduces energy consumption and costs, aligning with sdg-7's aim for sustainable and affordable energy.
# - **climate change fund pledge**: investing in climate change initiatives in emerging economies likely includes supporting clean energy projects, further reinforcing sdg-7 objectives.
#
# given that all these activities support the goals of sdg-7, the classification is "positive."<|im_end|>
#
# ###########################################################################################
# 252 107
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 253 125
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 254 134
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 255 624
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 256 753
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 257 809
#
# {
#   "label": "negative"
# }
# ```
#
# **rationale:**
#
# the text highlights major issues in youth unemployment and school-to-work transition in japan, despite a lower unemployment rate compared to the oecd average. this indicates that there are significant challenges and advancements against the goal of achieving full and productive employment and decent work for all youth, as per sdg-8.因此，我将其分类为"negative"。<|im_end|>
#
# ###########################################################################################
# 258 934
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 259 1082
#
# {
#   "label": "negative"
# }
# ```
#
# **reasoning**
#
# the text describes challenges and risks faced by youth in securing sufficient work and income, leading to poverty. it also mentions underemployment and exclusion from quality work opportunities, particularly for the poorest youth. these issues are contrary to the goals of sdg-8, which aims to promote full and productive employment and decent work for all. therefore, the text is classified as "negative" with respect to sdg-8.<|im_end|>
#
# ###########################################################################################
# 260 1198
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 261 1261
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 262 2027
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 263 2127
#  output would be:
#
# {
#   "label": "negative"
# }<|im_end|>
#
# ###########################################################################################
# 264 2236
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 265 2356
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 266 2530
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 267 3106
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 268 3122
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "at the same time, globalisation and trade have had an uneven impact across regions (deloitte/kraka, 2017(58]), although the current gap in unemployment rates across regions is among the smallest across oecd countries. while projections should be taken with much care, cross-country analysis suggests that around 10% of jobs in denmark face high probability of automation, which is among the lowest in oecd countries (figure 24). this partly reflects an already high level of digitalisation and use of industrial robots compared to other countries (see chapter)."
# sdg_classification: "sdg-8"
# output: <|im_end|>
# <|im_start|>assistant
# {
#     "label": "neutral"
# }<|im_end|>
#
# ###########################################################################################
# 269 3159
#
# {
#   "label": "negative"
# }
# ```
#
# **final output**
#
# \[ \boxed{ \{"label": "negative"\} } \]<|im_end|>
#
# ###########################################################################################
# 270 3317
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 271 3505
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 272 3590
#
# {
#   "label": "negative"
# }
# ```
#
# ### explanation
# the text describes negative employment and economic growth trends in two out of three countries (bangladesh and haiti), with only one showing positive growth (cambodia). given that the majority of the data points indicate decline or negative growth, which are against the objectives of sdg-8, the overall classification is "negative." this is because the text affirms situations that are contrary to the goals of sdg-8, implying a significant advancement against the goal.<|im_end|>
#
# ###########################################################################################
# 273 3679
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 274 3758
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 275 4361
#
#
# {
#
#   "label": "positive"
#
# }
#
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 276 4429
#
# {
#   "label": "neutral"
# }
# ```
# <|im_end|>
#
# ###########################################################################################
# 277 4439
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "although global factors may be difficult to address, countries could ease domestic constraints to private investment. in china, a priority is to address excess capacity in certain sectors, facilitate deleveraging and create a level playing field between state-owned enterprises and private firms. in india, a priority is to repair bank balance sheets, especially those of public sector banks. for all countries, in the medium term, increasing infrastructure investment and enhancing the business environment could stimulate private investment."
# sdg_classification: "sdg-8"
# output: <|im_end|>
# <|im_start|>assistant
# {
#   "label": "positive"
# }<|im_end|>
#
# ###########################################################################################
# 278 4564
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 279 5053
#
# {
#   "label": "negative"
# }
# ```
#
# **explanation**
#
# the text discusses disability benefits acting as a substitute for limited other supports for the long-term unemployed, with an increase in applications during recessions. this suggests deficiencies in providing adequate employment supports, which is contrary to the goals of sdg-8, hence classified as "negative".<|im_end|>
#
# ###########################################################################################
# 280 5063
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 281 5334
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 282 6056
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
# the input text describes initiatives to re-engage inactive youth through vocational education and outreach activities, which are directly aligned with the objectives of sdg-8. these activities aim to provide economic opportunities and full employment, thereby contributing positively to the goal of decent work and economic growth. therefore, the classification is "positive".<|im_end|>
#
# ###########################################################################################
# 283 6368
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 284 6570
#
# {
#   "label": "positive"
# }
# ```
# <|im_end|>
#
# ###########################################################################################
# 285 6621
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 286 6656
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 287 6749
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "the extremely strong reaction in spain meant that the climb in its unemployment rate was even larger than that observed in ireland, which suffered an output shock that was nearly three times larger. recessions that 01 until 2006 are included. by contrast, the unemployment response in the 2008-09 recession was muted in most european countries (including belgium, finland, germany, italy, the netherlands, norway and the slovak republic), as well as in japan and korea."
# sdg_classification: "sdg-8"
# output: <|im_end|>
# <|im_start|>assistant
# {
#   "label": "negative"
# }<|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 288 5
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 289 34
#
# {
#   "label": "positive"
# }
# ```
#
# **explanation:**
#
# the text indicates a substantial allocation of funds to transport, storage, and energy projects, which are key areas under sdg 9. although information and telecommunication projects received less financing, the majority of the funds are directed towards sectors that are essential for building resilient infrastructure and promoting industrialization, hence contributing positively to sdg 9.<|im_end|>
#
# ###########################################################################################
# 290 81
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 291 574
#
# {
#   "label": "positive"
# }
# ```
#
# **<|endoftext|>
#
# ###########################################################################################
# 292 899
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "this made input-output tables, rather than aggregate demand, hirschman’s policy framework of choice. since he was unconvinced that most developing countries had the capabilities to undertake big centralized investment programmes, he offered a more pragmatic approach to infrastructure planning that would help break the “interlocking vicious circles” of underdevelopment (hirschman, 1958: 5). this would occur by allowing infrastructure (“social overhead capital”) to lag behind in an investment sequence beginning with productive private investment primarily in the capital goods and intermediate goods sectors (see hirschman, 1958: 83)."
# sdg_classification: "sdg-9"
# output: <|im_end|>
# <|im_start|>assistant
# {
#     "label": "positive"
# }<|im_end|>
#
# ###########################################################################################
# 293 921
#
# {
#   "label": "positive"
# }
# ```
#
# **final answer**
#
# \[ \boxed{\{"label": "positive"\}} \]<|im_end|>
#
# ###########################################################################################
# 294 1023
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 295 1399
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 296 1489
#
# {
#   "label": "neutral"
# }
# ```
#
# **final answer**
#
# \[ \boxed{\{"label": "neutral"\}} \]<|im_end|>
#
# ###########################################################################################
# 297 1521
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 298 1607
#
# {
#   "label": "negative"
# }
# ```
#
# **final output**
#
# \[{
#   "\label": "negative"
# }\]<|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 299 1631
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "it further highlights the fact that by 2030, there will mechanisms to facilitate sustainable and resilient infrastructure development in developing countries through enhanced financial, technological and technical support, particularly to help least developed countries, landlocked developing countries and small island developing states overcome such large differences that these countries face in terms of infrastructure development vis-a-vis developed and other developing countries. in this context, goal 9 further emphasizes the need to support domestic technology development, research and innovation in developing countries, including by ensuring that the policy environment is conducive to, inter alia, industrial diversification and value addition to the export of raw commodities. in doing so, the forum should improve "alignment and coordination among established and new infrastructure initiatives, multilateral and national development banks, united nations agencies, and national institutions, development partners and the private sector".3 this will also help to promote linkages between goal 9 and the process of industrialization and innovation, especially for csn."
# sdg_classification: "sdg-9"
# output: <|im_end|>
# <|im_start|>assistant
# i've got this text to classify according to whether it's positive, negative, or neutral with respect to sdg-9. sdg-9 is about building resilient infrastructure, promoting inclusive and sustainable industrialization, and fostering innovation. so, i need to see if this text is pushing for these things, against them, or neither.
#
# first, i'll read the text carefully. it talks about mechanisms to facilitate sustainable and resilient infrastructure development in developing countries by 2030. there's going to be enhanced financial, technological, and technical support, especially for the least developed countries, landlocked developing countries, and small island developing states. these are areas that really need help with infrastructure, so it's positive that there are mechanisms to support them.
#
# it also mentions that by 2030, there will be ways to help these countries overcome the big differences they have in infrastructure compared to developed and other developing countries. that sounds like a step forward, so that's positive.
#
# moreover, goal 9 emphasizes the need to support domestic technology development, research, and innovation in developing countries. it says that policies should be favorable for industrial diversification and adding value to raw commodities. this seems like it's encouraging innovation and industrial growth, which is in line with sdg-9.
#
# the text also mentions that the forum should improve alignment and coordination among various entities like infrastructure initiatives, development banks, un agencies, national institutions, development partners, and the private sector. this suggests that there's going to be better cooperation and coordination in achieving these infrastructure and development goals, which is again positive.
#
# finally, it says that this will help promote linkages between goal 9 and the process of industrialization and innovation, especially for csn. i'm not sure what csn stands for, but assuming it's a group or category of countries, this seems like it's enhancing the connection between infrastructure and industrialization, which is probably a good thing.
#
# overall, the text is talking about supportive measures, enhanced support, and better coordination to achieve the goals of sdg-9. there's nothing here that suggests anything negative or against these goals. so, i would classify this as "positive."
#
# to confirm, let's recall the definitions:
#
# - positive: the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the sdg.
#
# - negative: the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the sdg.
#
# - neutral: the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the sdg.
#
# in this case, the text is clearly in favor of advancing the goals of sdg-9 through various supportive measures and coordination. therefore, "positive" is the appropriate label.
#
# **final answer**
#
# \[ \boxed{\{"label": "positive"\}} \]<|im_end|>
#
# ###########################################################################################
# 300 1977
#
# {
#   "label": "positive"
# }
# ```
#
# **reasoning**
#
# the text discusses how high-speed communication networks support innovation throughout the economy, similar to how electricity and transport networks spurred innovation in the past. it further states that future innovations in many sectors will be linked to the availability of high-speed, competitive data networks and the new applications they support. this aligns with the goals of sdg-9, which focuses on building resilient infrastructure, promoting inclusive and sustainable industrialization, and fostering innovation. therefore, the text is classified as "positive" because it implies significant advancement in favor of the sdg-9 goals.<|im_end|>
#
# ###########################################################################################
# 301 2155
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 302 2716
#
# {
#   "label": "positive"
# }
# ```
#
# **final answer**
#
# \[ \boxed{\{"label": "positive"\}} \]<|im_end|>
#
# ###########################################################################################
# 303 2930
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 304 3090
#  format with the key "label" indicating the classification.<|im_end|>
#
# ###########################################################################################
# 305 3580
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "it is imperative that discussions concerning universal, affordable access to the internet and to connecting devices remain front and centre, even as attention is focused on new technologies such as artificial intelligence (ai), the internet of things, robotics and blockchain. spaces to foster and ideate innovations need to be matched with equal policy vigour, particularly in enforcement."
# sdg_classification: "sdg-9"
# output: <|im_end|>
# <|im_start|>assistant
# okay, so i have this text to classify with respect to the sustainable development goals, specifically sdg-9, which is about building resilient infrastructure, promoting inclusive and sustainable industrialization, and fostering innovation. the text says:
#
# "it is imperative that discussions concerning universal, affordable access to the internet and to connecting devices remain front and centre, even as attention is focused on new technologies such as artificial intelligence (ai), the internet of things, robotics and blockchain. spaces to foster and ideate innovations need to be matched with equal policy vigour, particularly in enforcement."
#
# first, i need to understand what sdg-9 is all about. sdg-9 aims to build resilient infrastructure, promote inclusive and sustainable industrialization, and foster innovation. so, it's about making sure that countries have good roads, bridges, housing, and transportation systems, as well as promoting industries that are sustainable and inclusive, and encouraging innovation.
#
# now, looking at the text, it's talking about the importance of keeping discussions about universal and affordable internet access a priority, even as we focus on new technologies like ai, iot, robotics, and blockchain. it also mentions that spaces for fostering and ideating innovations need to be supported by strong policies, especially in enforcement.
#
# so, how does this relate to sdg-9? well, universal and affordable access to the internet and connecting devices is directly related to infrastructure, specifically information and communication technology infrastructure, which is a key component of sdg-9. promoting inclusive and sustainable industrialization can be greatly enhanced by having broad access to the internet, as it can help small businesses, remote areas, and underserved populations to connect and participate in the global economy.
#
# moreover, fostering innovation is explicitly mentioned in sdg-9, and the text emphasizes the need to support innovation spaces and match them with policy vigor, particularly in enforcement. this suggests that not only is innovation important, but also that there needs to be a regulatory framework to support and enforce these innovations, ensuring they are used in a way that benefits society as a whole.
#
# given that, i need to classify this text as positive, negative, or neutral with respect to sdg-9.
#
# a positive classification would mean that the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor of the goal indicated by the sdg.
#
# a negative classification would mean that the text implies or explicitly states that what is affirmed or described leads to a significant advancement against the goal indicated by the sdg.
#
# a neutral classification would mean that the text does not imply or explicitly state that what is affirmed or described leads to a significant advancement either in favor or against the goal indicated by the sdg.
#
# in this case, the text is emphasizing the importance of keeping discussions about universal and affordable internet access a priority, especially in the context of advancing new technologies and fostering innovation. it also stresses the need for policy support and enforcement for these innovations.
#
# this seems to be in direct alignment with sdg-9's goals of building resilient infrastructure (including ict infrastructure), promoting inclusive and sustainable industrialization, and fostering innovation.
#
# therefore, i would classify this text as "positive" because it is advocating for actions and policies that would support and advance the goals of sdg-9.
#
# so, the output should be:
#
# {
#
# "label": "positive"
#
# }<|im_end|>
#
# ###########################################################################################
# 306 3606
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 307 3830
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "in niger, evidence from the social cash transfer programme demonstrates that the greater privacy and control of mobile transfers compared to manual cash transfers shifts intra-household decision-making in favour of women (aker et al., technology-enabled crowdfunding platforms allow women to access trade finance. in china, the top funded industry sectors through peer-to-peer (p2p) consumer lending are in the retail and wholesale trade sectors, and 35 per cent of the fundraisers on the p2p consumer lending platforms are female (cambridge centre for alternative finance and the australian centre for financial studies, 2017). for example, through a project financed by the standards and trade development facility (stdf), improvements in pest management in uganda's flower sectors helped to raise the livelihood of the majority of women workers dependent on flower exports. the itc also launched the "shetrades" initiative, which seeks to connect one million women entrepreneurs to markets by 2020."
# sdg_classification: "sdg-9"
# output: <|im_end|>
# <|im_start|>assistant
# {
#   "label": "positive"
# }<|im_end|>
#
# ###########################################################################################
# 308 3958
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 309 4192
#  output should be:
#
# {
#
# "label": "neutral"
#
# }<|im_end|>
#
# ###########################################################################################
# 310 4410
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 311 4417
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 312 4747
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 313 4863
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 314 5117
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 315 5376
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 316 5399
#  output:
#
# {
#
# "label": "positive"
#
# }<|im_end|>
#
# ###########################################################################################
# 317 5493
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
# - **text analysis**: the text discusses targets and progress in areas such as resilient infrastructure, inclusive industrialization, financial support for small enterprises, research and development, and access to information and communication technology. these are all directly aligned with the objectives of sdg 9.
# - **classification**: given that all mentioned aspects support and promote the goals of sdg 9, the text is classified as "positive."
#
# this straightforward classification is based on the direct alignment of the text's content with the aims of sdg 9.<|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 318 5604
#
#
# {
#
#   "label": "positive"
#
# }
#
# ```
#
# **reasoning**
#
# the text extensively discusses the positive impacts of infrastructure development on economic growth and social development, aligning closely with the objectives of sdg-9. it mentions various benefits such as causality from infrastructure to output growth, long-term positive impacts on economic growth from investments in power and telecommunications, a multiplier effect stimulating private sector investment, reduction of rural-urban development gaps, job creation, wage increases, and enhanced access to basic social services for marginalized groups. there are no negative or neutral statements in the text regarding these impacts, leading to the classification of "positive."<|im_end|>
#
# ###########################################################################################
# 319 5737
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 320 5740
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 321 6033
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 322 6174
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 323 6440
#
# {
#   "label": "positive"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 324 329
#
# {
#   "label": "negative"
# }
# ```
#
# **justification:**
# the text underscores the持续存在的收入不平等现象，这与sdg-10减少不平等的目标相悖，因此被归类为负面。<|im_end|>
#
# ###########################################################################################
# 325 462
#  output would be:
#
# {
#
# "label": "positive"
#
# }
#
# <|im_end|>
#
# ###########################################################################################
# 326 478
#
# {"label": "neutral"}
# ```
#
# **final answer**
#
# \[ \boxed{"label": "neutral"} \]<|im_end|>
#
# ###########################################################################################
# 327 732
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 328 826
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
#
# 1. **understanding sdg-10**:
#    - sdg-10 aims to reduce inequalities within and among countries.
#    - key areas include income inequality, social inclusion, and access to resources.
#
# 2. **text analysis**:
#    - the text discusses a minimum income scheme that could reduce extreme poverty by up to 90%.
#    - minimum income protection is available in most eu countries.
#    - there is a note about assessing the welfare impact on disabled people who might lose entitlements.
#
# 3. **classification**:
#    - the primary focus is on the positive impact of minimum income schemes in reducing poverty, which aligns with reducing inequalities.
#    - the potential negative impact on disabled people is mentioned as a consideration but does not outweigh the overall positive impact.
#    - therefore, the text is classified as "positive" with respect to sdg-10.
#
# this approach ensures that the classification reflects the overall impact described in the text on the specified sdg.<|im_end|>
#
# ###########################################################################################
# 329 883
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 330 1052
#
# {
#   "label": "positive"
# }
# ```
#
# **reasoning:**
#
# - the text describes social assistance schemes targeting old-age protection and extreme poverty, which are measures to support vulnerable populations.
#
# - these schemes are part of efforts to reduce inequalities, which is the focus of sdg-10.
#
# - the transition from racially discriminatory schemes to more inclusive domestic initiatives suggests a positive move towards greater equality.
#
# - therefore, the text implies a significant advancement in favor of sdg-10, leading to the "positive" label.<|im_end|>
#
# ###########################################################################################
# 331 1187
#  output:
#
# {
#
#   "label": "negative"
#
# }
#
# **final answer** <|im_end|>
#
# ###########################################################################################
# 332 1353
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_start|>
# <|endoftext|>
#
# ###########################################################################################
# 333 1470
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 334 1821
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "however, this should be seen in the context of very high initial redistribution and thus a likely binding trade-off with economic efficiency. education, employment regulations and wage bargaining have also seen significant changes since the 1990s, and there are no doubt further challenges and need for reforms looming. however, the nordics have so far been able to adjust their policies in such a way that equality, opportunity and economic efficiency co-exist relatively well compared to the rest of the oecd."
# sdg_classification: "sdg-10"
# output: <|im_end|>
# <|im_start|>assistant
# {
#   "label": "positive"
# }<|im_end|>
#
# ###########################################################################################
# 335 1841
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "for instance, pension contributions of many professionals, such as engineers, which are set at a fixed amount depending on the number of years of activity, regardless of earnings, could usefully be rationalised. the recent activation of two centralised, inter-linked, electronic monitoring systems is a welcome step in this regard. more specifically, the “helios” scheme, monitoring retirement pay, is linked to the “ariadne” scheme, that directly records major demographic changes, facilitating in this way the detection and suspension of ineligible pensions (ec, 2013b). regional differences in the distribution of different categories of pensions in mid-2013, particularly regarding disability pensions, suggest the need for further monitoring of the social security system to avoid abuse in the future. the uninsured have a means-tested access to some basic health care services through the “health insurance book”, providing free access to public hospital and medical services (including pharmaceuticals)."
# sdg_classification: "sdg-10"
# output: <|im_end|>
# <|im_start|>assistant
# {
# "label": "positive"
# }<|im_end|>
#
# ###########################################################################################
# 336 2306
#
# {"label": "negative"}
# ```
#
# <|im_end|>
#
# ...
# output: <|im_end|>
# <|im_start|>assistant
# to classify the given input text with respect to the sdg-16 and assign one of the labels "positive", "negative", or "neutral", we need to understand the context of sdg-16 and analyze the text accordingly.
#
# sdg-16 is about promoting peaceful and inclusive societies for sustainable development, providing access to justice for all, and building effective, accountable institutions at all levels. the specific targets under sdg-16 include reducing violence, promoting the rule of law, and ensuring equal access to justice.
#
# given that, let's analyze the input text:
#
# "in recent years an increasing quantity of uk legislation has introduced blended or ‘hybridised’ procedures that blur the previously clear demarcation between civil and criminal legal processes, typically on the grounds of normatively-motivated political expediency. this paper provides a critical perspective on instances of procedural hybridisation in order to illustrate that, first, the reliance upon civil law measures to remedy criminal law infractions can raise human rights issues and, second, that such instrumental criminal justice strategies deliberately circumvent the enhanced procedural protections of the criminal law. by conceptualising the rule of law as a structural coupling between the political and legal systems, and due process rights as necessary and self-imposed limitations upon systemic operations, this paper employs a systems-theoretical approach to critique this balancing act between expediency and principle, and queries the circumstances under which legislation contravening the rule of law can be said to lack legitimacy."
#
# first, the text discusses the introduction of hybrid procedures in uk legislation that blend civil and criminal legal processes, often for political expediency. it then critically examines this trend, highlighting two main points:
#
# 1. relying on civil law measures to address criminal infractions can raise human rights issues.
#
# 2. such strategies circumvent the stronger protections afforded by criminal law procedures.
#
# the paper conceptualizes the rule of law as a connection between political and legal systems and views due process rights as essential constraints on these systems. it uses a systems-theoretical approach to critique the balance between expediency and principle and questions the legitimacy of legislation that violates the rule of law.
#
# now, relating this to sdg-16:
#
# - sdg-16 emphasizes the rule of law, access to justice, and accountable institutions.
#
# - the text critiques legislation that blurs the lines between civil and criminal procedures, arguing that this can raise human rights issues and circumvent protections.
#
# - it questions the legitimacy of such legislation when it contravenes the rule of law.
#
# given this analysis, the text seems to be pointing out potential drawbacks or risks in certain legislative approaches, suggesting that they may not align with the principles of the rule of law and could negatively impact human rights and justice.
#
# therefore, with respect to sdg-16, this text could be classified as "negative" because it implies that these hybrid procedures may lead to advancements against the goals of sdg-16, such as undermining the rule of law and potentially compromising access to justice and human rights protections.
#
# however, it's important to note that the text itself is academic and critical, aiming to illustrate issues rather than directly advocating for or against certain practices. but in the context of sdg-16, the implications of the arguments presented seem to suggest negative impacts on the goal.
#
# thus, the classification would be:
#
# {
#   "label": "negative"
# }<|im_end|>
#
# ###########################################################################################
# 566 5468
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "in four judgements of 13 january 2011 the european court of human rights (echr) in strasbourg returned to the issues raised in its earlier jurisprudence regarding preventive detention (“sicherungsverwahrung”) under german criminal law. in its decision of 17 december 2009, m. v. germany, the court had held that the german criminal law's retroactive extension of confinement in preventive detention failed to meet the requirement of lawful detention “after conviction” under art. 5 § 1 (a) of the convention for the protection of human rights and fundamental freedoms (hereinafter “the convention”), and violates the prohibition of retroactivity (art. 7 § 1 of the convention). the articles read as follows:"
# sdg_classification: "sdg-16"
# output: <|im_end|>
# <|im_start|>assistant
# given the input text and its sdg classification as sdg-16, i need to further classify the text into one of three labels: "positive", "negative", or "neutral", based on whether the text implies or explicitly states that what is affirmed or described leads to a significant advancement in favor or against the goal indicated by sdg-16.
#
# first, i need to understand what sdg-16 is about. sdg-16 is "peace, justice, and strong institutions." it aims to promote peaceful and inclusive societies for sustainable development, provide access to justice for all, and build effective, accountable, and inclusive institutions at all levels.
#
# now, let's analyze the input text:
#
# "in four judgments of 13 january 2011, the european court of human rights (echr) in strasbourg returned to the issues raised in its earlier jurisprudence regarding preventive detention (“sicherungsverwahrung”) under german criminal law. in its decision of 17 december 2009, m. v. germany, the court had held that the german criminal law's retroactive extension of confinement in preventive detention failed to meet the requirement of lawful detention “after conviction” under art. 5 § 1 (a) of the convention for the protection of human rights and fundamental freedoms (hereinafter “the convention”), and violates the prohibition of retroactivity (art. 7 § 1 of the convention). the articles read as follows:"
#
# this text is about the european court of human rights (echr) making judgments regarding preventive detention under german criminal law. specifically, it mentions that in a previous case (m. v. germany), the court found that the german criminal law's retroactive extension of preventive detention did not meet the requirements of lawful detention after conviction and violated the prohibition of retroactivity.
#
# to classify this text with respect to sdg-16, i need to see how this relates to peace, justice, and strong institutions.
#
# preventive detention is a measure that allows the continued detention of an individual even after they have served their sentence, based on the risk they pose to society. the echr's judgment seems to be critiquing the german law's retroactive application of this measure, finding it unlawful and in violation of human rights conventions.
#
# in the context of sdg-16, which emphasizes access to justice and the rule of law, this judgment can be seen as upholding legal standards and protecting individual rights. the echr's intervention suggests a commitment to ensuring that detention practices comply with international human rights standards, which is aligned with the goal of promoting justice and strong institutions.
#
# however, preventive detention itself is a complex issue. on one hand, it can be seen as a measure to protect society from individuals who are deemed dangerous, which could be interpreted as contributing to peaceful societies. on the other hand, if such detention is applied in a way that violates fundamental rights, it can be seen as a threat to justice and rule of law.
#
# in this specific case, the echr is criticizing the retroactive application of preventive detention, arguing that it violates the principle of legality and the prohibition of retroactivity. this suggests that the court is safeguarding individual rights and ensuring that detention practices are lawful and transparent, which are key components of sdg-16.
#
# therefore, the text implies that the echr's judgment is advancing the goals of sdg-16 by upholding legal standards and protecting human rights.
#
# based on this analysis, i would classify this text as "positive" with respect to sdg-16, as it indicates a significant advancement in favor of the goal of promoting peaceful and inclusive societies, access to justice for all, and building effective, accountable, and inclusive institutions.
#
# **final answer**
#
# \[ \boxed{\{"label": "positive"\}} \]<|im_end|>
#
# ###########################################################################################
# 567 5471
#
# {
#   "label": "neutral"
# }
# ```
#
# **final answer**
#
# \[ \boxed{\{"label": "neutral"\}} \]<|im_end|>
#
# ###########################################################################################
# 568 5502
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 569 5622
#
# {
#   "label": "negative"
# }
# ```
#
# **explanation**
#
# the input text discusses a massive outbreak of public protests and demonstrations in brazil in 2013, driven by government apathy, lack of transparency, and increasing corruption. these issues directly contrast with the objectives of sdg-16, which aims for peaceful and inclusive societies, access to justice, and strong institutions. the text highlights significant shortcomings in these areas, making it a clear case of advancement against the sdg-16 goals. hence, the classification is "negative".<|im_end|>
#
# ###########################################################################################
# 570 5721
#
# {
#   "label": "neutral"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 571 5801
#  format with 1 key:
#
#   - "label": the assigned label for the input text [this key/value pair is mandatory].
#
#
# input text: "it may be commonplace to state that the world will never be the same as it was before 11 september 2001. yet, it is obvious that the magnitude and audacity of the horrifying events of that day have presented international terrorism in an unprecedented way, namely as a real and potentially catastrophic threat to human security and international peace. this raises the question with regards to the role of international law, and to what extent current public international law provides an adequate framework for combating international terrorism. are further development and adaptation of principles and rules of international law necessary to deal more effectively with the threat of terrorist attacks and with those who do not play by these rules? these issues will be addressed in section 2 of this article."
# sdg_classification: "sdg-16"
# output: <|im_end|>
# <|im_start|>assistant
# okay, so i have this text to analyze, and it's related to sdg-16, which is peace, justice, and strong institutions. the task is to classify this text into one of three categories: positive, negative, or neutral, based on whether it advances or goes against the goal of sdg-16.
#
# first, i need to understand what sdg-16 is all about. sdg-16 aims to promote peaceful and inclusive societies for sustainable development, provide access to justice for all, and build effective, accountable, and inclusive institutions at all levels. so, anything that supports these objectives would be positive, anything that hinders them would be negative, and anything that doesn't really relate directly to these objectives would be neutral.
#
# now, looking at the text: "it may be commonplace to state that the world will never be the same as it was before 11 september 2001. yet, it is obvious that the magnitude and audacity of the horrifying events of that day have presented international terrorism in an unprecedented way, namely as a real and potentially catastrophic threat to human security and international peace. this raises the question with regards to the role of international law, and to what extent current public international law provides an adequate framework for combating international terrorism. are further development and adaptation of principles and rules of international law necessary to deal more effectively with the threat of terrorist attacks and with those who do not play by these rules? these issues will be addressed in section 2 of this article."
#
# so, this text is discussing the impact of the 9/11 attacks and how they have changed the way we view international terrorism. it's highlighting that terrorism is a significant threat to human security and international peace, which are both key components of sdg-16.
#
# the text then goes on to question the role of international law in combating terrorism and whether current laws are sufficient or if they need to be adapted and developed further to handle the threat more effectively.
#
# so, in terms of sdg-16, which is about peace, justice, and strong institutions, this text is acknowledging a major threat to peace and security and is considering how legal frameworks can be improved to address this threat.
#
# now, to classify this:
#
# - positive: would mean that the text suggests actions or views that significantly advance the goals of sdg-16.
#
# - negative: would mean that the text suggests actions or views that significantly hinder the goals of sdg-16.
#
# - neutral: would mean that the text doesn't really take a stance or suggest actions that directly advance or hinder the goals of sdg-16.
#
# in this case, the text is recognizing a threat to peace and security and is considering how to improve legal frameworks to combat that threat. this seems to be in alignment with the goals of sdg-16, as it's about strengthening institutions and promoting peace.
#
# however, it's not explicitly stating that something is being done to advance these goals; it's more of a discussion or analysis of the need for such advancements.
#
# given that, i would lean towards classifying this as "positive" because it's acknowledging the importance of addressing threats to peace and security and considering how international law can be improved to handle these threats, which aligns with the objectives of sdg-16.
#
# but, to be thorough, let's consider if it could be negative or neutral.
#
# negative would suggest that the text is promoting something that hinders peace and justice. but here, it's discussing the need to combat terrorism, which is consistent with promoting peace.
#
# neutral would mean that it's not really taking a stance or suggesting anything directly related to the goals. but since it's discussing ways to improve legal frameworks to combat terrorism, which is relevant to sdg-16, i don't think neutral is the right fit.
#
# therefore, "positive" seems most appropriate.
#
# so, the output should be:
#
# {
#
# "label": "positive"
#
# }<|im_end|>
#
# ###########################################################################################
# 572 6119
#
# {
#   "label": "positive"
# }
# ```<|im_end|>
#
# ###########################################################################################
# 573 6551
#  output would be:
#
# {
#
# "label": "neutral"
#
# }
#
# i think this is the most appropriate classification given the information provided in the text.<|im_end|>
#
# ###########################################################################################
# 574 6618
#
# {
#   "label": "negative"
# }
# ```
#
# <|im_end|>
#
# ###########################################################################################
# 575 6628
#
# {
#   "label": "positive"
# }
# ```
#
# ### explanation
# the text outlines the creation of global institutions, treaties, and norms in fields such as global environment, human security, international law, and cultural diversity. these developments are positive steps that align with the objectives of sdg 16, which seeks to foster peaceful societies, ensure access to justice, and strengthen institutions. therefore, the classification is "positive" as the text implies significant advancement in favor of sdg 16.<|im_end|>

# %%
STOP!
# Out:
#   File "<ipython-input-46-3bfd59f24194>", line 1
#     STOP!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
#  You can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Continue the fibonnaci sequence: 1, 1, 2, 3, 5, 8,"},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)

# %%
# AGGIUNGERE QUI IL CODICE PER VALUTARE IL MODELLO CON IL DATASET DI TEST

# %% [markdown]
# <a name="Save"></a>
# ### Saving, loading finetuned models
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.
#
# **[NOTE]** This ONLY saves the LoRA adapters, and not the full model. To save to 16bit or GGUF, scroll down!

# %%
model.save_pretrained("lora_model") # Local saving
tokenizer.save_pretrained("lora_model")
# model.push_to_hub("your_name/lora_model", token = "...") # Online saving
# tokenizer.push_to_hub("your_name/lora_model", token = "...") # Online saving

# %% [markdown]
# Now if you want to load the LoRA adapters we just saved for inference, set `False` to `True`:

# %%
if False:
    from unsloth import FastLanguageModel
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference

messages = [
    {"role": "user", "content": "Describe a tall tower in the capital of France."},
]
inputs = tokenizer.apply_chat_template(
    messages,
    tokenize = True,
    add_generation_prompt = True, # Must add for generation
    return_tensors = "pt",
).to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer, skip_prompt = True)
_ = model.generate(input_ids = inputs, streamer = text_streamer, max_new_tokens = 128,
                   use_cache = True, temperature = 1.5, min_p = 0.1)

# %% [markdown]
# You can also use Hugging Face's `AutoModelForPeftCausalLM`. Only use this if you do not have `unsloth` installed. It can be hopelessly slow, since `4bit` model downloading is not supported, and Unsloth's **inference is 2x faster**.

# %%
if False:
    # I highly do NOT suggest - use Unsloth if possible
    from peft import AutoPeftModelForCausalLM
    from transformers import AutoTokenizer
    model = AutoPeftModelForCausalLM.from_pretrained(
        "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        load_in_4bit = load_in_4bit,
    )
    tokenizer = AutoTokenizer.from_pretrained("lora_model")

# %% [markdown]
# ### Saving to float16 for VLLM
#
# We also support saving to `float16` directly. Select `merged_16bit` for float16 or `merged_4bit` for int4. We also allow `lora` adapters as a fallback. Use `push_to_hub_merged` to upload to your Hugging Face account! You can go to https://huggingface.co/settings/tokens for your personal tokens.

# %%
# Merge to 16bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_16bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_16bit", token = "")

# Merge to 4bit
if False: model.save_pretrained_merged("model", tokenizer, save_method = "merged_4bit",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "merged_4bit", token = "")

# Just LoRA adapters
if False: model.save_pretrained_merged("model", tokenizer, save_method = "lora",)
if False: model.push_to_hub_merged("hf/model", tokenizer, save_method = "lora", token = "")

# %% [markdown]
# ### GGUF / llama.cpp Conversion
# To save to `GGUF` / `llama.cpp`, we support it natively now! We clone `llama.cpp` and we default save it to `q8_0`. We allow all methods like `q4_k_m`. Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods (full list on our [Wiki page](https://github.com/unslothai/unsloth/wiki#gguf-quantization-options)):
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.
#
# [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)

# %%
# Save to 8bit Q8_0
if False: model.save_pretrained_gguf("model", tokenizer,)
# Remember to go to https://huggingface.co/settings/tokens for a token!
# And change hf to your username!
if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

# Save to 16bit GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

# Save to q4_k_m GGUF
if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")

# Save to multiple GGUF options - much faster if you want multiple!
if False:
    model.push_to_hub_gguf(
        "hf/model", # Change hf to your username!
        tokenizer,
        quantization_method = ["q4_k_m", "q8_0", "q5_k_m",],
        token = "", # Get a token at https://huggingface.co/settings/tokens
    )

# %% [markdown]
# Now, use the `model-unsloth.gguf` file or `model-unsloth-Q4_K_M.gguf` file in `llama.cpp` or a UI based system like `GPT4All`. You can install GPT4All by going [here](https://gpt4all.io/index.html).
#
# **[NEW] Try 2x faster inference in a free Colab for Llama-3.1 8b Instruct [here](https://colab.research.google.com/drive/1T-YBVfnphoVc8E2E854qF3jdia2Ll2W2?usp=sharing)**

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/u54VK8m8tk) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other links:
# 1. Zephyr DPO 2x faster [free Colab](https://colab.research.google.com/drive/15vttTpzzVXv_tJwEk-hIcQ0S9FcEWvwP?usp=sharing)
# 2. Llama 7b 2x faster [free Colab](https://colab.research.google.com/drive/1lBzz5KeZJKXjvivbYvmGarix9Ao6Wxe5?usp=sharing)
# 3. TinyLlama 4x faster full Alpaca 52K in 1 hour [free Colab](https://colab.research.google.com/drive/1AZghoNBQaMDgWJpi4RbffGM1h6raLUj9?usp=sharing)
# 4. CodeLlama 34b 2x faster [A100 on Colab](https://colab.research.google.com/drive/1y7A0AxE3y8gdj4AVkl2aZX47Xu3P1wJT?usp=sharing)
# 5. Mistral 7b [free Kaggle version](https://www.kaggle.com/code/danielhanchen/kaggle-mistral-7b-unsloth-notebook)
# 6. We also did a [blog](https://huggingface.co/blog/unsloth-trl) with 🤗 HuggingFace, and we're in the TRL [docs](https://huggingface.co/docs/trl/main/en/sft_trainer#accelerate-fine-tuning-2x-using-unsloth)!
# 7. `ChatML` for ShareGPT datasets, [conversational notebook](https://colab.research.google.com/drive/1Aau3lgPzeZKQ-98h69CCu1UJcvIBLmy2?usp=sharing)
# 8. Text completions like novel writing [notebook](https://colab.research.google.com/drive/1ef-tab5bhkvWmBOObepl1WgJvfvSzn5Q?usp=sharing)
# 9. [**NEW**] We make Phi-3 Medium / Mini **2x faster**! See our [Phi-3 Medium notebook](https://colab.research.google.com/drive/1hhdhBa1j_hsymiW9m-WzxQtgqTH_NHqi?usp=sharing)
# 10. [**NEW**] We make Gemma-2 9b / 27b **2x faster**! See our [Gemma-2 9b notebook](https://colab.research.google.com/drive/1vIrqH5uYDQwsJ4-OO3DErvuv4pBgVwk4?usp=sharing)
# 11. [**NEW**] To finetune and auto export to Ollama, try our [Ollama notebook](https://colab.research.google.com/drive/1WZDi7APtQ9VsvOrQSSC5DDtxq159j8iZ?usp=sharing)
# 12. [**NEW**] We make Mistral NeMo 12B 2x faster and fit in under 12GB of VRAM! [Mistral NeMo notebook](https://colab.research.google.com/drive/17d3U-CAIwzmbDRqbZ9NnpHxCkmXB6LZ0?usp=sharing)
#
# <div class="align-center">
#   <a href="https://github.com/unslothai/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/u54VK8m8tk"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://ko-fi.com/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Kofi button.png" width="145"></a></a> Support our work if you can! Thanks!
# </div>
